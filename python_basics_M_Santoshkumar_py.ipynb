# %% [markdown]
# <a href="https://colab.research.google.com/github/SantoshM09/python-basics-assignment/blob/main/python_basics_M_Santoshkumar_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Santosh"
age=20
height=1.72
is_student=True
print(name,age,height,is_student)
# Out:
# Santosh 20 1.72 True

# %%
print(f"name: {name} | age: {age} | height: {height} | student: {is_student}")
# Out:
# name: Santosh | age: 20 | height: 1.72 | student: True

# %%
age_in_month=age*12
age_in_days=age*365
remainder=age%7
age_power=age**2
print(age_in_month)
print(age_in_days)
print(remainder)
print(age_power)
# Out:
# 240
# 7300
# 6
# 400
